# %% [markdown]
# <a href="https://colab.research.google.com/github/Yashyupr/Analytics-Using-Python/blob/master/Data_Cleaning_for_Visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q kaggle

# %%
from google.colab import files

#Upload the Kaggle API credentials JSON file
files.upload()

# %%capture
# Hidden Cell: This cell contains sensitive information
username = "your_username"
password = "your_password"
# Out:
#      <input type="file" id="files-69e283f5-c823-4fe5-a212-293395759038" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-69e283f5-c823-4fe5-a212-293395759038">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !mkdir -p ~/.kaggle
# !mv kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d arindamsahoo/social-media-users
# Out:
# ...
#   0% 0.00/2.89M [00:00<?, ?B/s]
# 100% 2.89M/2.89M [00:00<00:00, 198MB/s]

# %%
# !unzip /content/social-media-users.zip -d social-media-users
# Out:
# Archive:  /content/social-media-users.zip
#   inflating: social-media-users/SocialMediaUsersDataset.csv

# %%
import pandas as pd
df = pd.read_csv ('/content/social-media-users/SocialMediaUsersDataset.csv')

# %%
df.head()
# Out:
#    UserID                Name  Gender         DOB  \
# 0       1       Jesse Lawhorn  Female  1958-10-15
# 1       2         Stacy Payne  Female  2004-07-21
# 2       3  Katrina Nicewander  Female  2000-02-07
# 3       4      Eric Yarbrough    Male  1985-04-14
# 4       5       Daniel Adkins  Female  1955-09-18
#
#                                            Interests         City    Country
# 0            'Movies', 'Fashion', 'Fashion', 'Books'      Sibolga  Indonesia
# 1  'Gaming', 'Finance and investments', 'Outdoor ...     Al Abyār      Libya
# 2    'DIY and crafts', 'Music', 'Science', 'Fashion'  Wādī as Sīr     Jordan
# 3       'Outdoor activities', 'Cars and automobiles'       Matera      Italy
# 4                              'Politics', 'History'      Biruaca  Venezuela

# %%
# Create a new column 'Interests' as a list of interests
df['Interests'] = df.apply(lambda row: [row[col] for col in interest_columns if pd.notna(row[col])], axis=1)

# Create separate columns for each interest category
unique_interests = set([interest for sublist in df['Interests'].tolist() for interest in sublist])
for interest in unique_interests:
    if pd.notna(interest):
        df[interest] = df['Interests'].apply(lambda x: x.count(interest))

# Drop the original 'Interests' column
df = df.drop('Interests', axis=1)

# Display the resulting DataFrame
print(df)
# Out:
#        UserID                Name  Gender         DOB                  City  \
# 0           1       Jesse Lawhorn  Female  1958-10-15               Sibolga
# 1           2         Stacy Payne  Female  2004-07-21              Al Abyār
# 2           3  Katrina Nicewander  Female  2000-02-07           Wādī as Sīr
# 3           4      Eric Yarbrough    Male  1985-04-14                Matera
# 4           5       Daniel Adkins  Female  1955-09-18               Biruaca
# ...       ...                 ...     ...         ...                   ...
# 99995   99996      Lionel Denault  Female  1983-07-31                 Dawan
# 99996   99997     Margie Mieszala  Female  1954-05-20  Arcos de la Frontera
# 99997   99998       Joan Mercedes    Male  1975-06-06             Los Andes
# 99998   99999        Marvin Massa  Female  1959-11-16               Varjota
# 99999  100000          Josh Young  Female  1988-07-29                 Brzeg
#
#          Country                     Interest_0  \
# ...

# %%
df.head()
# Out:
#    UserID                Name  Gender         DOB         City    Country  \
# 0       1       Jesse Lawhorn  Female  1958-10-15      Sibolga  Indonesia
# 1       2         Stacy Payne  Female  2004-07-21     Al Abyār      Libya
# 2       3  Katrina Nicewander  Female  2000-02-07  Wādī as Sīr     Jordan
# 3       4      Eric Yarbrough    Male  1985-04-14       Matera      Italy
# 4       5       Daniel Adkins  Female  1955-09-18      Biruaca  Venezuela
#
#            Interest_0               Interest_1          Interest_2 Interest_3  \
# 0              Movies                  Fashion             Fashion      Books
# 1              Gaming  Finance and investments  Outdoor activities     Travel
# 2      DIY and crafts                    Music             Science    Fashion
# 3  Outdoor activities     Cars and automobiles                 NaN        NaN
# 4            Politics                  History                 NaN        NaN
#
# ...

# %%
# Replace NaN values with empty string
df.fillna('', inplace=True)

# Display the DataFrame
print(df)
# Out:
#        UserID                Name  Gender         DOB                  City  \
# 0           1       Jesse Lawhorn  Female  1958-10-15               Sibolga
# 1           2         Stacy Payne  Female  2004-07-21              Al Abyār
# 2           3  Katrina Nicewander  Female  2000-02-07           Wādī as Sīr
# 3           4      Eric Yarbrough    Male  1985-04-14                Matera
# 4           5       Daniel Adkins  Female  1955-09-18               Biruaca
# ...       ...                 ...     ...         ...                   ...
# 99995   99996      Lionel Denault  Female  1983-07-31                 Dawan
# 99996   99997     Margie Mieszala  Female  1954-05-20  Arcos de la Frontera
# 99997   99998       Joan Mercedes    Male  1975-06-06             Los Andes
# 99998   99999        Marvin Massa  Female  1959-11-16               Varjota
# 99999  100000          Josh Young  Female  1988-07-29                 Brzeg
#
#          Country                     Interest_0  \
# ...

# %%
df.head()
# Out:
#    UserID                Name  Gender         DOB         City    Country  \
# 0       1       Jesse Lawhorn  Female  1958-10-15      Sibolga  Indonesia
# 1       2         Stacy Payne  Female  2004-07-21     Al Abyār      Libya
# 2       3  Katrina Nicewander  Female  2000-02-07  Wādī as Sīr     Jordan
# 3       4      Eric Yarbrough    Male  1985-04-14       Matera      Italy
# 4       5       Daniel Adkins  Female  1955-09-18      Biruaca  Venezuela
#
#            Interest_0               Interest_1          Interest_2 Interest_3  \
# 0              Movies                  Fashion             Fashion      Books
# 1              Gaming  Finance and investments  Outdoor activities     Travel
# 2      DIY and crafts                    Music             Science    Fashion
# 3  Outdoor activities     Cars and automobiles
# 4            Politics                  History
#
#    ... Food and dining  Nature  Beauty  Finance and investments  \
# ...

# %%
# Assuming your DataFrame is named df
df.to_csv('/content/social-media-users/SocialMediaUsersDataset.csv', index=False)

# %%
df = pd.read_csv ('/content/social-media-users/SocialMediaUsersDataset.csv')
